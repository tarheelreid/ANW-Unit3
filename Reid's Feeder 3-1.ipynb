# %% [markdown]
# # American Ninja Warrior: Creating A New Data Subset From Obstacle History
#
# The following notebook will teach you how to filter a data set into a new subset of data using some of the basic processes of coding in Python.
#
# First things first, we will go over how to correctly set up your Python Notebook on your computer, and how to launch the correct Jupyter Lab coding environment you'll need to begin your coding adventure of learning how to create a new subset of data.
#
# ### Overview of Tutorial
#
# Throughout this notebook tutorial on filtering data, we will use this step-by-step tutorial to cover the following:
#
# *Technical Instructions:*
# 1. Importing the Pandas Package.
# 2. Importing your chosen set of data from a publicly available data set.
# 3. Ways of exploring and getting to know your data.
# 4. Using computational techniques to navigate, create, and export your newly filtered data sub-set.

# %% [markdown]
# ### Acknowledgements
#
# This Python tutorial has been taught and assigned by Professor Gotzler of the UNC-Chapel Hill English Department.
#
# For more detailed examples and exercies, see the Davis Library Research Hub's Python lessons at [Python: Intro to Data lessons](https://unc-libraries-data.github.io/Python/Intro/Introduction_CrashCourse.html)

# %% [markdown]
# ### Step #1: Importing the Pandas Package
#
# By importing packages into your session, you are able to use additional tools and functions not available in base Python.
#
# One you've installed a package, you can load it into your current Python session with the import function.
#
# The package that you will be importing today is the Pandas Package. The Pandas Package is a very useful package that enables better management, manipulation, filtering, and cleaning of data much easier then simply using base Python. Additionally, Pandas also provides a range of useful tools for working with data once it has been stored in the session.
#
# You'll begin by importing the Pandas Package with the following command:

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# Pay close attention to the way we imported the Pandas Package. You load pandas with the usual `import pandas` and an extra `as pd` statement. This allows us to write cells using `pandas` with `pd.` instead of `pandas.` for ease while writing functions. Incluidng `as pd` is **not** necessary to load the Pandas Package.
#
# Another extra thing you can add - **seen above** - for a better experience while exploring your data is `numpy`. In choosing to import the `numpy` package, `numpy` will help `pandas` do some of its math while you're exploring your data.

# %% [markdown]
# ### Step #2: Importing Your Chosen Set of Data From a Publicly Available Data Set
#
# If you haven't already, download your chosen .csv file of data and save it to a file in your computer. Make sure it's organized well so you can read through it easily when your navigating to your data. If you don't know where to look, you can look through a great collection of interesting data collected by various Github users at [GitHub's Awesome Data Collections](https://github.com/awesomedata/awesome-public-datasets) or if you can't choose, you can ask Professor Gotzler and he'll give you some data sets that he's chosen himself.
#
# For this tutorial we will be exploring data from a .csv file of every single American Ninja Warrior Obstacle used in competition.
#
# If you saved your .csv file correctly, you should see it in your folder in your Jupyter Lab. The relative path you will use to import the data into your session is the name of the data-set in your folder. For this example, your relative path will be AmericanNinjaWarrior.csv.
#
# You'll import the data-set into your session with the following function: `pd.read_csv()`. Remember to include `df=` in order to define your object. You'll insert the relative path, or in other words, the data-set file name into the parentheses of the function.

# %%
df=pd.read_csv("AmericanNinjaWarrior.csv")

# %% [markdown]
# ### Step #3: Ways of Exploring and Getting to Known Your Data
#
# There are many different attributes to use in order to explore your data. Attributes provide you numbers, information, and values inside your dataframe in order to better know your data.
#
# - `.columns` provides all of the column names in your data.
# - `.shape` provides a number for the amount of rows and columns are available in your dataset.
# - `.size` provides the amount of total cells are in your data (rows * columns).
# - `.head()` provides the first 5 columns in your data set.
# - `.tail()` provides the last 5 columns in your data set.
# - `.sample(n=10)` provides a random 10 individual columns of data in your dataset
#
# Reminder, to include `df` in order to define your attributes. These attributes should look like so:

# %%
df.columns
# Out:
# Index(['Season', 'Location', 'Round/Stage', 'Obstacle Name', 'Obstacle Order',
#        'Unnamed: 5', 'Unnamed: 6'],
#       dtype='object')

# %%
df.shape
# Out:
# (904, 7)

# %%
df.size
# Out:
# 6328

# %%
df.head()
# Out:
#    Season Location Round/Stage    Obstacle Name  Obstacle Order  Unnamed: 5  \
# 0     1.0   Venice  Qualifying  Quintuple Steps             1.0         NaN
# 1     1.0   Venice  Qualifying       Rope Swing             2.0         NaN
# 2     1.0   Venice  Qualifying   Rolling Barrel             3.0         NaN
# 3     1.0   Venice  Qualifying   Jumping Spider             4.0         NaN
# 4     1.0   Venice  Qualifying      Pipe Slider             5.0         NaN
#
#    Unnamed: 6
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN

# %%
df.tail()
# Out:
#      Season Location Round/Stage Obstacle Name  Obstacle Order  Unnamed: 5  \
# 899     NaN      NaN         NaN           NaN             NaN         NaN
# 900     NaN      NaN         NaN           NaN             NaN         NaN
# 901     NaN      NaN         NaN           NaN             NaN         NaN
# 902     NaN      NaN         NaN           NaN             NaN         NaN
# 903     NaN      NaN         NaN           NaN             NaN         NaN
#
#      Unnamed: 6
# 899         NaN
# 900         NaN
# 901         NaN
# 902         NaN
# 903         NaN

# %%
df.sample(n=10)
# Out:
#      Season           Location                 Round/Stage     Obstacle Name  \
# 99      3.0  Sasuke 27 (Japan)   National Finals - Stage 1   Spinning Bridge
# 385     6.0              Miami      Finals (Regional/City)      Spider Climb
# 538     7.0          Las Vegas   National Finals - Stage 3  Doorknob Grasper
# 26      1.0  Sasuke 23 (Japan)   National Finals - Stage 2      Stick Slider
# 771    10.0        Los Angeles  Qualifying (Regional/City)   Spinning Bridge
# 209     4.0          Southeast      Finals (Regional/City)       Cargo Climb
# 878    10.0          Las Vegas   National Finals - Stage 2     Wingnut Alley
# 541     7.0          Las Vegas   National Finals - Stage 3      Pole Grasper
# 811    10.0              Miami      Finals (Regional/City)   Slippery Summit
# 285     5.0             Denver  Qualifying (Regional/City)     Jump Hang Kai
#
#      Obstacle Order  Unnamed: 5  Unnamed: 6
# 99              7.0         NaN         NaN
# 385            10.0         NaN         NaN
# 538             2.0         NaN         NaN
# 26              3.0         NaN         NaN
# 771             3.0         NaN         NaN
# 209            10.0         NaN         NaN
# 878             5.0         NaN         NaN
# 541             5.0         NaN         NaN
# 811             5.0         NaN         NaN
# 285             4.0         NaN         NaN

# %% [markdown]
# Or, if you wanted a sample of more - say 15 or 20 - it would look like this:

# %%
df.sample(n=15)
# Out:
#      Season       Location                 Round/Stage       Obstacle Name  \
# 861    10.0    Minneapolis      Finals (Regional/City)       Salmon Ladder
# 679     9.0    San Antonio      Finals (Regional/City)     Spinball Wizard
# 327     6.0         Venice  Qualifying (Regional/City)         Warped Wall
# 695     9.0  Daytona Beach      Finals (Regional/City)       Circuit Board
# 313     5.0      Las Vegas   National Finals - Stage 3   Roulette Cylinder
# 285     5.0         Denver  Qualifying (Regional/City)       Jump Hang Kai
# 377     6.0          Miami      Finals (Regional/City)  Downhill Pipe Drop
# 140     4.0        Midwest      Finals (Regional/City)           Jump Hang
# 214     4.0      Las Vegas   National Finals - Stage 1    Half-Pipe Attack
# 501     7.0        Houston      Finals (Regional/City)         Warped Wall
# 489     7.0         Venice      Finals (Regional/City)    Invisible Ladder
# 202     4.0      Southeast      Finals (Regional/City)       Bungee Bridge
# 552     8.0    Los Angeles      Finals (Regional/City)      Floating Steps
# 665     9.0    San Antonio  Qualifying (Regional/City)      Floating Steps
# 401     6.0         Denver      Finals (Regional/City)        Spider Climb
#
#      Obstacle Order  Unnamed: 5  Unnamed: 6
# 861             7.0         NaN         NaN
# 679             9.0         NaN         NaN
# 327             6.0         NaN         NaN
# 695             9.0         NaN         NaN
# 313             1.0         NaN         NaN
# 285             4.0         NaN         NaN
# 377             2.0         NaN         NaN
# 140             4.0         NaN         NaN
# 214             5.0         NaN         NaN
# 501             6.0         NaN         NaN
# 489            10.0         NaN         NaN
# 202             3.0         NaN         NaN
# 552             1.0         NaN         NaN
# 665             1.0         NaN         NaN
# 401            10.0         NaN         NaN

# %%
df.sample(n=20)
# Out:
#      Season           Location                 Round/Stage  \
# 801    10.0              Miami  Qualifying (Regional/City)
# 308     5.0          Las Vegas   National Finals - Stage 2
# 365     6.0          St. Louis      Finals (Regional/City)
# 381     6.0              Miami      Finals (Regional/City)
# 526     7.0          Las Vegas   National Finals - Stage 1
# 194     4.0          Southeast  Qualifying (Regional/City)
# 302     5.0          Las Vegas   National Finals - Stage 1
# 591     8.0       Indianapolis      Finals (Regional/City)
# 300     5.0          Las Vegas   National Finals - Stage 1
# 796    10.0             Dallas      Finals (Regional/City)
# 221     4.0          Las Vegas   National Finals - Stage 2
# 205     4.0          Southeast      Finals (Regional/City)
# 708     9.0        Kansas City      Finals (Regional/City)
# 50      2.0             Venice                 Semi-Finals
# 325     6.0             Venice  Qualifying (Regional/City)
# 241     5.0             Venice      Finals (Regional/City)
# 864    10.0        Minneapolis      Finals (Regional/City)
# 598     8.0      Oklahoma City  Qualifying (Regional/City)
# 108     3.0  Sasuke 27 (Japan)   National Finals - Stage 3
# 30      1.0  Sasuke 23 (Japan)   National Finals - Stage 3
#
#                    Obstacle Name  Obstacle Order  Unnamed: 5  Unnamed: 6
# 801               Floating Steps             1.0         NaN         NaN
# 308         Double Salmon Ladder             2.0         NaN         NaN
# 365                  Warped Wall             6.0         NaN         NaN
# 381                  Warped Wall             6.0         NaN         NaN
# 526                  Sonic Curve             5.0         NaN         NaN
# 194                     Log Grip             2.0         NaN         NaN
# 302             Half-Pipe Attack             5.0         NaN         NaN
# 591               Hourglass Drop             8.0         NaN         NaN
# 300                  Rope Glider             3.0         NaN         NaN
# 796                  Warped Wall             6.0         NaN         NaN
# 221              Unstable Bridge             3.0         NaN         NaN
# 205                    Wall Lift             6.0         NaN         NaN
# 708                  Warped Wall             6.0         NaN         NaN
# 50                  Jumping Bars             5.0         NaN         NaN
# 325  Jumping Bars into Cargo Net             4.0         NaN         NaN
# 241                 Frame Slider             2.0         NaN         NaN
# 864                  Spider Trap            10.0         NaN         NaN
# 598                      Bar Hop             5.0         NaN         NaN
# 108                     Arm Bike             1.0         NaN         NaN
# 30                     Arm Rings             1.0         NaN         NaN

# %% [markdown]
# ### Step #4: Using Computational Techniques to Navigate, Create, and Export Your Newly Filtered Data Sub-Set
#
# With so much data, it's often hard to narrow down and actually find what you're looking for. Despite the challenge, using Python, Pandas, and Numpy, you have the ability to take some "short cuts" to find what you're looking for quick and easy. That's where the following commands come in handy when looking through a big .csv file.
#
# In this tutorial I will show you how to narrow down you big data-set into a subset of specific information.
#
# Say you wanted to see all of the obstacle information in your data-set for the city of Atlanta.
#
# - The inner command you would write is `df["Location"] == "Atlanta"`.
# - The outer command encompassing the inner command is `df[`.
# - When combined, the following commands result in all of information for the city of Atlanta in your data set.

# %%
df[df["Location"] == "Atlanta"]
# Out:
#      Season Location                 Round/Stage         Obstacle Name  \
# 562     8.0  Atlanta  Qualifying (Regional/City)        Floating Steps
# 563     8.0  Atlanta  Qualifying (Regional/City)            Big Dipper
# 564     8.0  Atlanta  Qualifying (Regional/City)             Block Run
# 565     8.0  Atlanta  Qualifying (Regional/City)            Spin Cycle
# 566     8.0  Atlanta  Qualifying (Regional/City)           Pipe Fitter
# 567     8.0  Atlanta  Qualifying (Regional/City)           Warped Wall
# 568     8.0  Atlanta      Finals (Regional/City)        Floating Steps
# 569     8.0  Atlanta      Finals (Regional/City)            Big Dipper
# 570     8.0  Atlanta      Finals (Regional/City)             Block Run
# 571     8.0  Atlanta      Finals (Regional/City)            Spin Cycle
# 572     8.0  Atlanta      Finals (Regional/City)           Pipe Fitter
# 573     8.0  Atlanta      Finals (Regional/City)           Warped Wall
# 574     8.0  Atlanta      Finals (Regional/City)         Salmon Ladder
# 575     8.0  Atlanta      Finals (Regional/City)  Floating Monkey Bars
# 576     8.0  Atlanta      Finals (Regional/City)           The Clacker
# 577     8.0  Atlanta      Finals (Regional/City)      Invisible Ladder
#
#      Obstacle Order  Unnamed: 5  Unnamed: 6
# 562             1.0         NaN         NaN
# 563             2.0         NaN         NaN
# 564             3.0         NaN         NaN
# 565             4.0         NaN         NaN
# 566             5.0         NaN         NaN
# 567             6.0         NaN         NaN
# 568             1.0         NaN         NaN
# 569             2.0         NaN         NaN
# 570             3.0         NaN         NaN
# 571             4.0         NaN         NaN
# 572             5.0         NaN         NaN
# 573             6.0         NaN         NaN
# 574             7.0         NaN         NaN
# 575             8.0         NaN         NaN
# 576             9.0         NaN         NaN
# 577            10.0         NaN         NaN

# %%
df["Obstacle Name"].value_counts().head(20)
# Out:
# Warped Wall             86
# Salmon Ladder           41
# Quintuple Steps         32
# Floating Steps          28
# Log Grip                21
# Jump Hang               18
# Quad Steps              16
# Jumping Spider          14
# Invisible Ladder        11
# Wall Lift               11
# Rolling Log             11
# Rope Ladder             10
# Bridge of Blades        10
# Cargo Climb              9
# Rope Climb               9
# Spider Climb             9
# Ultimate Cliffhanger     9
# Spinning Log             8
# Spinning Bridge          8
# Jumping Bars             8
# Name: Obstacle Name, dtype: int64

# %%
ValueTable = df["Obstacle Name"].value_counts().head(20)

# %%
ValueTable
# Out:
# Warped Wall             86
# Salmon Ladder           41
# Quintuple Steps         32
# Floating Steps          28
# Log Grip                21
# Jump Hang               18
# Quad Steps              16
# Jumping Spider          14
# Invisible Ladder        11
# Wall Lift               11
# Rolling Log             11
# Rope Ladder             10
# Bridge of Blades        10
# Cargo Climb              9
# Rope Climb               9
# Spider Climb             9
# Ultimate Cliffhanger     9
# Spinning Log             8
# Spinning Bridge          8
# Jumping Bars             8
# Name: Obstacle Name, dtype: int64

# %%
ValueTable.to_csv("ValueTable.csv", index=False)

# %% [markdown]
# Say you wanted to see all of the obstacle information used in the city of Miami's competitions.
#
# You would use the exact same combined commands as above but replace `"Atlanta"` with `"Miami"`. Resulting in this:

# %%
df[df["Location"] == "Miami"]
# Out:
#      Season Location                 Round/Stage            Obstacle Name  \
# 266     5.0    Miami  Qualifying (Regional/City)          Quintuple Steps
# 267     5.0    Miami  Qualifying (Regional/City)      Utility Pole Slider
# 268     5.0    Miami  Qualifying (Regional/City)           Balance Bridge
# 269     5.0    Miami  Qualifying (Regional/City)              Slider Jump
# 270     5.0    Miami  Qualifying (Regional/City)              Monkey Pegs
# 271     5.0    Miami  Qualifying (Regional/City)              Warped Wall
# 272     5.0    Miami      Finals (Regional/City)          Quintuple Steps
# 273     5.0    Miami      Finals (Regional/City)      Utility Pole Slider
# 274     5.0    Miami      Finals (Regional/City)           Balance Bridge
# 275     5.0    Miami      Finals (Regional/City)              Slider Jump
# 276     5.0    Miami      Finals (Regional/City)              Monkey Pegs
# 277     5.0    Miami      Finals (Regional/City)              Warped Wall
# 278     5.0    Miami      Finals (Regional/City)            Salmon Ladder
# 279     5.0    Miami      Finals (Regional/City)               Ledge Jump
# 280     5.0    Miami      Finals (Regional/City)            Rolling Steel
# 281     5.0    Miami      Finals (Regional/City)             Spider Climb
# 370     6.0    Miami  Qualifying (Regional/City)          Quintuple Steps
# 371     6.0    Miami  Qualifying (Regional/City)       Downhill Pipe Drop
# 372     6.0    Miami  Qualifying (Regional/City)           Dancing Stones
# 373     6.0    Miami  Qualifying (Regional/City)                Jump Hang
# 374     6.0    Miami  Qualifying (Regional/City)           Curtain Slider
# 375     6.0    Miami  Qualifying (Regional/City)              Warped Wall
# 376     6.0    Miami      Finals (Regional/City)          Quintuple Steps
# 377     6.0    Miami      Finals (Regional/City)       Downhill Pipe Drop
# 378     6.0    Miami      Finals (Regional/City)           Dancing Stones
# 379     6.0    Miami      Finals (Regional/City)                Jump Hang
# 380     6.0    Miami      Finals (Regional/City)           Curtain Slider
# 381     6.0    Miami      Finals (Regional/City)              Warped Wall
# 382     6.0    Miami      Finals (Regional/City)            Salmon Ladder
# 383     6.0    Miami      Finals (Regional/City)                Minefield
# 384     6.0    Miami      Finals (Regional/City)          Floating Stairs
# 385     6.0    Miami      Finals (Regional/City)             Spider Climb
# 801    10.0    Miami  Qualifying (Regional/City)           Floating Steps
# 802    10.0    Miami  Qualifying (Regional/City)               Fly Wheels
# 803    10.0    Miami  Qualifying (Regional/City)             Razor's Edge
# 804    10.0    Miami  Qualifying (Regional/City)                Ring Turn
# 805    10.0    Miami  Qualifying (Regional/City)          Slippery Summit
# 806    10.0    Miami  Qualifying (Regional/City)  Warped Wall / Mega Wall
# 807    10.0    Miami      Finals (Regional/City)             Archer Steps
# 808    10.0    Miami      Finals (Regional/City)          Cannonball Drop
# 809    10.0    Miami      Finals (Regional/City)             Razor's Edge
# 810    10.0    Miami      Finals (Regional/City)                Ring Turn
# 811    10.0    Miami      Finals (Regional/City)          Slippery Summit
# 812    10.0    Miami      Finals (Regional/City)              Warped Wall
# 813    10.0    Miami      Finals (Regional/City)            Salmon Ladder
# 814    10.0    Miami      Finals (Regional/City)             Crazy Clocks
# 815    10.0    Miami      Finals (Regional/City)             Stair Hopper
# 816    10.0    Miami      Finals (Regional/City)              Spider Trap
#
#      Obstacle Order  Unnamed: 5  Unnamed: 6
# 266             1.0         NaN         NaN
# 267             2.0         NaN         NaN
# 268             3.0         NaN         NaN
# 269             4.0         NaN         NaN
# 270             5.0         NaN         NaN
# 271             6.0         NaN         NaN
# 272             1.0         NaN         NaN
# 273             2.0         NaN         NaN
# 274             3.0         NaN         NaN
# 275             4.0         NaN         NaN
# 276             5.0         NaN         NaN
# 277             6.0         NaN         NaN
# 278             7.0         NaN         NaN
# 279             8.0         NaN         NaN
# 280             9.0         NaN         NaN
# 281            10.0         NaN         NaN
# 370             1.0         NaN         NaN
# 371             2.0         NaN         NaN
# 372             3.0         NaN         NaN
# 373             4.0         NaN         NaN
# 374             5.0         NaN         NaN
# 375             6.0         NaN         NaN
# 376             1.0         NaN         NaN
# 377             2.0         NaN         NaN
# 378             3.0         NaN         NaN
# 379             4.0         NaN         NaN
# 380             5.0         NaN         NaN
# 381             6.0         NaN         NaN
# 382             7.0         NaN         NaN
# 383             8.0         NaN         NaN
# 384             9.0         NaN         NaN
# 385            10.0         NaN         NaN
# 801             1.0         NaN         NaN
# 802             2.0         NaN         NaN
# 803             3.0         NaN         NaN
# 804             4.0         NaN         NaN
# 805             5.0         NaN         NaN
# 806             6.0         NaN         NaN
# 807             1.0         NaN         NaN
# 808             2.0         NaN         NaN
# 809             3.0         NaN         NaN
# 810             4.0         NaN         NaN
# 811             5.0         NaN         NaN
# 812             6.0         NaN         NaN
# 813             7.0         NaN         NaN
# 814             8.0         NaN         NaN
# 815             9.0         NaN         NaN
# 816            10.0         NaN         NaN

# %% [markdown]
# Awesome job at your first time filtering data, you did great!
#
# Now, you need to export your new data set into an exportable .csv file. And in order to do this, you need to give a name to your new subset. By using `copy.()`, you are able to take a "snapshot" of your original data file that you filtered from. For this tutorial, you are only going to export the information from the city of Atlanta.
#
# To use your Atlanta data subset later, use the following commands as so:

# %%
ATL_subset = df[df["Location"] == "Atlanta"]

# %% [markdown]
# Now that you've given a name to your newly manipulated data. You need to export your data as a .csv file.
#
# In order to do this you use the command `.to_csv()`. Then, add your new data name within the parentheses at the end.
#
# So for example, for your filtered subset we would run: `ATL_subset.to_csv("ATL_subset.csv")` this will export a `.csv` file in our working directory.
#
# By default, this newly created .csv file will include the row of indices that the Pandas Package created when we command the original file into your session using `.read_csv`.
#
# In order to get rid of this mechanic, we can add `index=false` to our statement, which tells it not bring in those extra index numbers that is not needed.
#
# It will look this so:

# %%
ATL_subset.to_csv("ATL_subset.csv", index=False)

# %% [markdown]
# Amazing job! You have now successfully finished the tutorial and should see your new data in the form of a .csv file in your folder. And if you don't see it, no problem, just carefully check over your work and go over the tutorial step-by-step to figure out where you went wrong.
#
# If you want, you can create a new session in Jupyter Lab using Python and by running the command `pd.read_csv` you can start manipulating your own data you created yourself!

# %% [markdown]
# ### Thank You and Further Resources!
#
# This tutorial was created and brought to you by Reid Miller. A big thank you to Prof. Gotzler for teaching and assigning this very interesting and cool assignment.
#
# If your interested in more information and tutorials on Pandas, check out these sources provided by the Davis Library Research Hub on [Pandas](https://unc-libraries-data.github.io/Python/Jupyter/Pandas.html) and [Pandas: Extra_Topics](https://unc-libraries-data.github.io/Python/Jupyter/Extra_Topics.html).
